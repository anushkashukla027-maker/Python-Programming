# %%
class student:
    school_name="upes"

    def __init__(self,name,age):
        self.name=name
        self.age=age

s1 = student("aman",20) 
s2 = student("riya",21)

print("school: ", student.school_name)
print("student 1:", s1.name,s1.age)
print("student 2:", s2.name,s2.age)
# Out:
# school:  upes
# student 1: aman 20
# student 2: riya 21

# %%
class employee:
    company = "ABS LTD"

    def __init__(self,name,salary):
        self.name = name
        self.salary = salary

    def show_details(self):
        print("name:", self.name)
        print("salary:", self.salary)
        print("company:",employee.company)
        print("-----------------")

    @classmethod
    def change_company(cls,new_name):
        cls.company = new_name


emp1 = employee("riya", 30000)
emp2 = employee("aman",40000)

print("before changing company")
emp1.show_details()
emp2.show_details()
 
employee.change_company("xyz pvt")

print("after changing company")
emp1.show_details()
emp2.show_details()
# Out:
# before changing company
# name: riya
# salary: 30000
# company: ABS LTD
# -----------------
# name: aman
# salary: 40000
# company: ABS LTD
# -----------------
# after changing company
# name: riya
# salary: 30000
# company: xyz pvt
# -----------------
# name: aman
# salary: 40000
# company: xyz pvt
# -----------------

# %%
class mathhelper:
    @staticmethod
    def is_even(num):
        return num % 2==0

print(mathhelper.is_even(8))
print(mathhelper.is_even(11))
# Out:
# True
# False

# %%
class bankaccount:
    def __init__(self,name,balance):
        self.name = name
        self._balance = balance

    def deposit(self ,amount):
        self._balance += amount   
        print(f"{amount} deposited.")

    def withdraw(self , amount):
        if amount <= self._balance:
            self._balance -= amount
            print(f"{amount} withdrawn.")    
        else:
            print("insufficient")

    def show_balance(self):
        print(f"balance: {self._balance}")            

account = bankaccount("alice",1000)

account.deposit(500)
account.withdraw(300)
account.withdraw(1500)

account.show_balance()
# Out:
# 500 deposited.
# 300 withdrawn.
# insufficient
# balance: 1200

# %%
class student:
    "this is the student class docstring."
    pass

print(student.__name__)
print(student.__doc__)
print(student.__module__)
print(student.__dict__)
# Out:
# student
# this is the student class docstring.
# __main__
# {'__module__': '__main__', '__doc__': 'this is the student class docstring.', '__dict__': <attribute '__dict__' of 'student' objects>, '__weakref__': <attribute '__weakref__' of 'student' objects>}

# %%
class product:
    def __init__(self,name,price):
        self.name = name
        self.price = price
    def __str__(self):
        return f"product: {self.name},price: {self.price}"

    def __add__(self,other):
        return self.price + other.price

    def __eq__(self,other):
        return self.price == other.price

p1 = product("laptop", 50000)
p2 = product("phone",300000)
p3 = product("tablet", 50000)

print(p1)
print(p1+p2)
print(p1 == p3)
print(p1 == p2)
# Out:
# product: laptop,price: 50000
# 350000
# True
# False
